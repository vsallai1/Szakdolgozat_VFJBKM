# %%
import http.client
import json
import requests
import pandas as pd

authUsername = 'read-ae6952dc6e60bac365b398101568fce4'
authPassword = 'IGjC6o9efh1VzPZ+HpxuxMBxmB/aGhJjGWlBGIkf'
pages = 20000
page_size = 1
weight="aran"

with open('yarn_codes.txt','r') as file:
    ids=file.read().splitlines()

for page in range(14563,pages):
    #define URL for the API request
    url = 'https://api.ravelry.com/yarns/search.json?page={}&page_size={}&weight={}'.format(page, page_size,weight) 

    r1 = requests.get(url, auth=requests.auth.HTTPBasicAuth(authUsername, authPassword))
    if r1.status_code != 200:
        print(f"Error on page {page}: {r1.status_code}")
        break
  

    r1.close()
    read=json.loads((r1.text)) #makes the json more readable

    patternid=read["yarns"]
    id=patternid[0]["id"]
    ids.append(str(id))

print(ids)
print(type(ids[0]))
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File c:\Users\robot\anaconda3\Lib\site-packages\urllib3\connection.py:196, in HTTPConnection._new_conn(self)
#     195 try:
# --> 196     sock = connection.create_connection(
#     197         (self._dns_host, self.port),
#     198         self.timeout,
#     199         source_address=self.source_address,
#     200         socket_options=self.socket_options,
#     201     )
#     202 except socket.gaierror as e:
#
# File c:\Users\robot\anaconda3\Lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# File c:\Users\robot\anaconda3\Lib\site-packages\urllib3\util\connection.py:73, in create_connection(address, timeout, source_address, socket_options)
# ...

# %%
ids = list(dict.fromkeys(ids))
file = open('yarn_codes2.txt','w')
for item in ids:
	file.write(item+"\n")
file.close()
